# %% [markdown]
# # Weekdays vs Weekends

# %% [markdown]
# ## Libraries import

# %%
library(tidyverse)
library(dplyr)
library(ggplot2)
library(Hmisc)
# Out:
# -- Attaching core tidyverse packages ---------------------------------------------------------------- tidyverse 2.0.0 --
# v dplyr     1.1.2     v readr     2.1.4
# v forcats   1.0.0     v stringr   1.5.1
# v ggplot2   3.4.2     v tibble    3.2.1
# v lubridate 1.9.2     v tidyr     1.3.0
# v purrr     1.0.1
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Error in library(Hmisc): aucun package nommé 'Hmisc' n'est trouvé
# Traceback:
#
# 1. library(Hmisc)

# %%
Sys.setlocale("LC_TIME","C")
options(stringsAsFactors=FALSE)
theme_set(theme_bw()) # just my preference for plots

# %% [markdown]
# ## Data import and structuring

# %%
read_met <- function(filename) {
  data <- read_table(filename, skip=15, 
    col_names= c("year", "month", "day", "hour", "minute", "WIRI", "WIGE"),
    col_types = paste(collapse = "", c(rep("i", 5), rep("n", 2))))
  data %>%
    mutate(datetime = make_datetime(year, month, day, hour, minute, tz = "CEST"),
           year     = year(datetime),
           month    = month(datetime),
           day      = day(datetime),
           hour     = hour(datetime),
           minute   = minute(datetime),
           WIRI     = ifelse(WIRI <= -9999, NA, WIRI),
           WIGE     = ifelse(WIGE <= -9999, NA, WIGE))
}

# %%
month2season <- function(month) {
  ## month is an integer (1-12)
  ## a factor with levels {"Winter : DJF", "Spring : MAM", "Summer : JJA", "Autumn : SON"} is returned
  seasons <- c("Winter", "Spring", "Summer", "Autumn")
  index <- findInterval(month %% 12, seq(0, 12, 3))
  factor(seasons[index], seasons)
}

wday2type <- function(wday) {
  ## wday is an integer with 1 = Monday, 2 = Tuesday, ... and 7 = Sunday
  c("Weekday", "Weekend")[(unclass(wday) - 1) %/% 5 + 1]
}

# %%
read_tseries <- function(filename, timecolumn = "Date/time", timeformat = "%d.%m.%Y %H:%M", tz = "Etc/GMT-1", delta = 3600) {
  ## read the table, strip units in column names, rename time column
  ##   and change data type of time column from a string of characters to
  ##   a numeric type so that we can perform operations on it

  data <- read_delim(filename, skip = 5, delim = ";", locale = locale(encoding = "Latin1"), show_col_types = FALSE)

  out <- data %>%
    rename_with(.fn = function(x) sub("[ ].*$", "", x)) %>% # strip units for simplification
    rename(datetime = !!timecolumn) %>%
    mutate(datetime = parse_date_time(datetime, !!timeformat, !!tz) - !!delta) %>%
    mutate(year = year(datetime),
           month = month(datetime),
           day = day(datetime),
           hour = hour(datetime),
           dayofwk = wday(datetime, label = TRUE, week_start = 1),
           daytype = wday2type(dayofwk),
           season = month2season(month),
           .after = datetime)
}

# %%
datapath <- file.path("Data")

all_data_df <- full_join(
  bind_cols(site="DAV", read_tseries(file.path(datapath, "DAV.csv"))),
  bind_cols(site="BAS", read_tseries(file.path(datapath, "BAS.csv")))
)

#all_data_df
# Out:
# Joining with `by = join_by(site, datetime, year, month, day, hour, dayofwk, daytype, season, O3, NO2, PM10, NOX, TEMP,
# PREC, RAD)`

# %%
all_data_lf <- all_data_df %>%
  pivot_longer(-c(site, datetime, season, year, month, day, hour, dayofwk, daytype),  # id columns
               names_to = "variable",
               values_to = "value")

# %% [markdown]
# ## Pollutants' results

# %%
# both sites on the same graph
daytype<-all_data_lf %>%
  filter(!is.na(value) & !is.na(season) & !variable %in% c("CPC", "EC", "NOX", "PREC"))
  
daytype_plot<-ggplot(daytype) +
  facet_grid(variable ~ season, scales = "free_y", labeller = labeller(
    variable = c(
      "NO2" =  "NO2 [ug/m3]",
      "O3" = "O3 [ug/m3]",
      "PM10" = "PM10 [ug/m3]",
      "PM2.5" = "PM2.5 [ug/m3]",
      "PREC" = "PREC [mm]",
      "RAD" = "RAD [W/m2]",
      "SO2" = "SO2 [ug/m3]",
      "TEMP" = "TEMP [C]"
    )
  )) + 
  geom_boxplot(
    aes(x = daytype, y = value, color = site),
    outlier.size = 0.5, 
    outlier.shape = 3
  ) +
    labs(
    x = "",  # Label for the x-axis
    y = "",  # Label for the y-axis
    title = "Day Type Differences through all Seasons"  # Title for the plot
  ) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))

daytype_plot

ggsave("outputs/daytype.jpeg", plot = daytype_plot, width = 9, height = 9, dpi = 300)
# Out:
# plot without title

# %% [markdown]
# ## Precipitation analysis

# %%
Precipitation_data <- all_data_lf %>%
  filter(!is.na(value) & variable == "PREC" & !is.na(season)) %>%
  group_by(daytype, variable, season, site) %>%
  summarise(
    mean_value = mean(value, na.rm = TRUE),
    sd_value = sd(value, na.rm = TRUE),
    n = sum(!is.na(value)),  # Sample size (excluding NA)
    se_value = sd_value / sqrt(n),  # Standard error
    ci_value = qt(0.975, df = n - 1) * se_value  # 95% Confidence Interval
  )

precipitations_plot_1 <-ggplot(Precipitation_data,
    aes(
    x = daytype, 
    y = mean_value, 
    color = site,
    fill=site
  )
) +
  facet_grid(variable ~ season, scales = "free_y") +
  # Adjust the dodge width for bars and error bars to avoid superimposition
  geom_bar(
    stat = "identity", 
    show.legend = TRUE, 
    position = position_dodge(width = 0.8),  # Separate bars for each site
    width = 0.35  # Adjust bar width to avoid overlap
  ) +  # Mean values as bars
  geom_errorbar(
    aes(ymin = mean_value - ci_value, ymax = mean_value + ci_value), 
    width = 0.2, 
    position = position_dodge(width = 0.8),  # Align error bars with the bars for each site
    color = "black"
  ) +  # 95% CI error bars
  labs(
    x = "Day Type",  # Label for the x-axis
    y = "Log10 of Precipitation (mm)",  # Label for the y-axis
    title = "Hourly Mean Precipitation by Day Type and Season"  # Title for the plot
  ) +
  scale_y_continuous("Hourly mean precipitation (mm)", expand = expansion(mult = c(0, 0.1))) +
  theme_minimal() +
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    strip.text.y = element_text(size = 12, face = "bold"),  # Make facet labels bolder
    panel.border = element_rect(color = "black", fill = NA, size = 1)  # Add box around each facet
  )

precipitations_plot_1

ggsave("outputs/precipitations_DayType_sites.jpeg", plot = precipitations_plot_1, width = 6, height = 5, dpi = 300)
# Out:
# `summarise()` has grouped output by 'daytype', 'variable', 'season'. You can override using the `.groups` argument.
# Warning message:
# "The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# i Please use the `linewidth` argument instead."
# plot without title

# %%
library(ggplot2)
library(dplyr)

# Filter the data for the PREC variable
daytype <- all_data_lf %>%
  filter(!is.na(value) & !is.na(season) & variable == "PREC")

# Create the plot for PREC only, with a log y scale and clear separation of seasons
daytype_plot <- ggplot(daytype) +
  facet_grid(~ season, scales = "free_y", labeller = labeller(
    variable = c(
      "PREC" = "PREC [mm]"
    )
  )) + 
  # Add the rectangle around each season facet
  geom_boxplot(
    aes(x = daytype, y = value, color = site),
    outlier.size = 0.5, 
    outlier.shape = 3,
    position = position_dodge(width = 0.7)  # Separate the boxplots for each season
  ) +
  scale_y_log10() +  # Apply log scale to y-axis
  labs(
    x = "Day Type",  # Label for the x-axis
    y = "Log10 of Precipitation (mm)",  # Label for the y-axis
    title = "Precipitation Distribution by Day Type and Season"  # Title for the plot
  ) +
  theme_minimal() +
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    strip.text.y = element_text(size = 12, face = "bold"),  # Make facet labels bolder
    panel.border = element_rect(color = "black", fill = NA, size = 1)  # Add box around each facet
  )

# Print the plot
daytype_plot

# Save the plot
ggsave("outputs/daytype_prec_log_separated_seasons_with_boxes.jpeg", plot = daytype_plot, width = 6, height = 5, dpi = 300)
# Out:
# Warning message:
# "Transformation introduced infinite values in continuous y-axis"
# Warning message:
# "Removed 15456 rows containing non-finite values (`stat_boxplot()`)."
# Warning message:
# "Transformation introduced infinite values in continuous y-axis"
# Warning message:
# "Removed 15456 rows containing non-finite values (`stat_boxplot()`)."
# plot without title

# %% [markdown]
# ### Accumulated precipitations

# %%
# Filter out NA values and calculate cumulative sum using reframe()
Precipitation_cumsum_data <- all_data_lf %>%
  filter(!is.na(value) & variable == "PREC" & !is.na(season)) %>%
  group_by(daytype, season, site) %>%
  reframe(
    cumsum_value = cumsum(value)  # Compute cumulative sum for each group
  )

# Create the plot
precipitations_plot_2 <- ggplot(Precipitation_cumsum_data, aes(
    x = daytype, 
    y = cumsum_value, 
    color = site,
    fill = site
  )) +
  facet_grid(~ season, scales = "free_y") +
  geom_bar(
    stat = "identity", 
    show.legend = TRUE, 
    position = position_dodge(width = 0.8),  # Separate bars for each site
    width = 0.35  # Adjust bar width to avoid overlap
  ) +
  scale_y_continuous("Precipitation (mm)", expand = expansion(mult = c(0, 0.1))) +  # Adjust label to reflect cumulative values
  theme_minimal() +
    labs(
    x = "Day Type",  # Label for the x-axis
    y = "Precipitation (mm)",  # Label for the y-axis
    title = "Accumulated Precipitation by Day Type and Season"  # Title for the plot
  ) +
  theme(
    axis.text.x = element_text(angle = 45, hjust = 1),
    strip.text.y = element_text(size = 12, face = "bold"),  # Make facet labels bolder
    panel.border = element_rect(color = "black", fill = NA, size = 1)  # Add box around each facet
  )

# Print the plot
precipitations_plot_2

ggsave("outputs/accumulated_precipitations_1.jpeg", plot = precipitations_plot_2, width = 6, height = 5, dpi = 300)
# Out:
# plot without title

# %% [markdown]
# ## Weekly variations

# %%
head(all_data_lf)
# Out:
#   site datetime   year month day hour dayofwk daytype season variable value
# 1 DAV  2024-01-01 2024 1     1   0    lun\\.  Weekday Winter O3       57.7
# 2 DAV  2024-01-01 2024 1     1   0    lun\\.  Weekday Winter NO2       1.9
# 3 DAV  2024-01-01 2024 1     1   0    lun\\.  Weekday Winter PM10      1.2
# 4 DAV  2024-01-01 2024 1     1   0    lun\\.  Weekday Winter NOX       1.9
# 5 DAV  2024-01-01 2024 1     1   0    lun\\.  Weekday Winter TEMP     -2.2
# 6 DAV  2024-01-01 2024 1     1   0    lun\\.  Weekday Winter PREC      0.0

# %%
Percentile <- function(perc) function(x) 
  ## `perc` is the percentile which should be computed for the numeric vector `x`
  quantile(x, perc*1e-2, na.rm=TRUE)

# %%
Diurnal_profile_DAV <- all_data_lf %>%
  filter(site=="DAV" & !is.na(value) & !is.na(season)) %>%
  ggplot(aes(x=hour, y=value, group=daytype, color=daytype)) +
  facet_grid(variable ~ season, scale = "free_y", drop=TRUE) +
  geom_line(stat="summary", fun="median")+
  geom_errorbar(stat="summary",
                fun.min=Percentile(25),
                fun.max=Percentile(75))+
  ggtitle("DAVOS")

Diurnal_profile_DAV
ggsave("outputs/Diurnal_profile_DAV.jpeg", plot = Diurnal_profile_DAV, width = 8, height = 6, dpi = 400)
# Out:
# plot without title

# %%
Diurnal_profile_BAS <- all_data_lf %>%
  filter(site=="BAS" & !is.na(value) & !is.na(season)) %>%
  ggplot(aes(x=hour, y=value, group=daytype, color=daytype)) +
  facet_grid(variable ~ season, scale = "free_y", drop=TRUE) +
  geom_line(stat="summary", fun="median")+
  geom_errorbar(stat="summary",
                fun.min=Percentile(25),
                fun.max=Percentile(75))+
  ggtitle("BASEL")

Diurnal_profile_BAS
ggsave("outputs/Diurnal_profile_BAS.jpeg", plot = Diurnal_profile_BAS, width = 8, height = 6, dpi = 400)
# Out:
# plot without title

# %%
all_data_lf$variable <- factor(
  all_data_lf$variable,
  levels = c("NO2", "NOX", "O3", "PM10", setdiff(unique(all_data_lf$variable), c("NO2", "NOX", "O3", "PM10")))
)

# %%
Diurnal_profile_BAS <- all_data_lf %>%
  filter(site == "BAS" & !is.na(value) & !is.na(season)) %>%
  ggplot(aes(x = hour, y = value, group = daytype, color = daytype)) +
  facet_grid(variable ~ season, scale = "free_y", drop = TRUE) +
  geom_line(stat = "summary", fun = "median") +
  geom_errorbar(
    stat = "summary",
    fun.min = function(x) quantile(x, 0.25, na.rm = TRUE),
    fun.max = function(x) quantile(x, 0.75, na.rm = TRUE)
  ) +
  ggtitle("BASEL")

Diurnal_profile_BAS
ggsave("outputs/Diurnal_profile_BAS.jpeg", plot = Diurnal_profile_BAS, width = 8, height = 6, dpi = 400)
# Out:
# plot without title

# %%
Ozone_weekly_variation <-all_data_lf %>%
  filter(variable=="O3"& !is.na(season)) %>%
  ggplot(aes(x=hour, y=value, group=site, color=site)) +
  facet_grid(season ~ dayofwk, drop=TRUE) +
  geom_line(stat="summary", fun="median")+
  geom_errorbar(stat="summary",
                fun.min=Percentile(25),
                fun.max=Percentile(75))+
  ggtitle("O3 weekly variations")

Ozone_weekly_variation
ggsave("outputs/Ozone_weekly_variation_hourly.jpeg", plot = Ozone_weekly_variation, width = 8, height = 6, dpi = 400)
# Out:
# Warning message:
# "Removed 85 rows containing non-finite values (`stat_summary()`)."
# Warning message:
# "Removed 85 rows containing non-finite values (`stat_summary()`)."
# Warning message:
# "Removed 85 rows containing non-finite values (`stat_summary()`)."
# Warning message:
# "Removed 85 rows containing non-finite values (`stat_summary()`)."
# plot without title

# %%
mean_sd <- function(x) {
  m <- mean(x, na.rm = TRUE)
  s <- sd(x, na.rm = TRUE)
  data.frame(y = m, ymin = m - s, ymax = m + s)
}

# %%
ozone_daily_mean_weekly_variation <-all_data_lf %>%
  filter(variable == "O3" & !is.na(season)) %>%
  ggplot(aes(x = dayofwk, y = value, group = site, color = site)) +
  facet_grid(season ~ variable, drop = TRUE) +
  stat_summary(fun = mean, geom = "line") +
  stat_summary(fun.data = mean_sd, geom = "errorbar", width = 0.2) +
  ggtitle("O3") +
  ylab("O₃ concentration (µg/m³)")

ozone_daily_mean_weekly_variation
ggsave("outputs/ozone_daily_mean_weekly_variation.jpeg", plot = ozone_daily_mean_weekly_variation, width = 8, height = 6, dpi = 400)
# Out:
# Warning message:
# "Removed 85 rows containing non-finite values (`stat_summary()`)."
# Warning message:
# "Removed 85 rows containing non-finite values (`stat_summary()`)."
# Warning message:
# "Removed 85 rows containing non-finite values (`stat_summary()`)."
# Warning message:
# "Removed 85 rows containing non-finite values (`stat_summary()`)."
# plot without title

# %%
library(dplyr)
library(ggplot2)

# Step 1: Extract daily max per pollutant, site, and day
daily_max <- all_data_lf %>%
  group_by(site, season, variable, year, month, day) %>%
  summarise(
    day_max = max(value, na.rm = TRUE),
    dayofwk = first(dayofwk),  # Get corresponding weekday
    .groups = "drop"
  )

# Step 2: Compute mean and sd of daily max by day of the week
weekly_stats <- daily_max %>%
  group_by(season, site,variable, dayofwk) %>%
  summarise(
    mean_val = mean(day_max, na.rm = TRUE),
    sd_val = sd(day_max, na.rm = TRUE),
    .groups = "drop"
  )
# Out:
# Warning message:
# "There were 1487 warnings in `summarise()`.
# The first warning was:
# i In argument: `day_max = max(value, na.rm = TRUE)`.
# i In group 771: `site = "BAS"`, `season = Winter`, `variable = PM2.5`, `year = 2024`, `month = 2`, `day = 12`.
# Caused by warning in `max()`:
# ! aucun argument pour max ; -Inf est renvoyé
# i Run `dplyr::last_dplyr_warnings()` to see the 1486 remaining warnings."

# %%
head(weekly_stats)
# Out:
#   season site variable dayofwk mean_val sd_val
# 1 Winter BAS  NO2      lun\\.  33.20714 15.48272
# 2 Winter BAS  NO2      mar\\.  36.98571 13.31771
# 3 Winter BAS  NO2      mer\\.  39.10769 15.84716
# 4 Winter BAS  NO2      jeu\\.  36.88462 13.61952
# 5 Winter BAS  NO2      ven\\.  40.68333 14.08770
# 6 Winter BAS  NO2      sam\\.  33.88333 11.78966

# %%
# Step 3: Plot mean ± sd for each pollutant across weekdays
ozone_daily_max_weekly_variation<-weekly_stats %>%
filter(variable == "O3") %>%
ggplot(aes(x = dayofwk, y = mean_val, group = site, color = site)) +
facet_grid(season ~ variable, drop = TRUE) +
  geom_line() +
  geom_point() +
  geom_errorbar(aes(ymin = mean_val - sd_val, ymax = mean_val + sd_val), width = 0.2) +
  ylab("Mean of Daily Max Values ± SD") +
  xlab("Day of Week") +
  ggtitle("Mean Daily Max of Pollutants by Weekday") +
  theme_minimal()

ozone_daily_max_weekly_variation
ggsave("outputs/ozone_daily_max_weekly_variation.jpeg", plot = ozone_daily_max_weekly_variation, width = 8, height = 6, dpi = 400)
# Out:
# plot without title

# %% [markdown]
# ## T-test to see whether weekend concentrations are statistically different from weekdays's

# %%
head(all_data_df)
# Out:
#   site datetime            year month day hour dayofwk daytype season O3   NO2
# 1 DAV  2024-01-01 00:00:00 2024 1     1   0    lun\\.  Weekday Winter 57.7 1.9
# 2 DAV  2024-01-01 01:00:00 2024 1     1   1    lun\\.  Weekday Winter 55.2 2.1
# 3 DAV  2024-01-01 02:00:00 2024 1     1   2    lun\\.  Weekday Winter 49.9 3.7
# 4 DAV  2024-01-01 03:00:00 2024 1     1   3    lun\\.  Weekday Winter 52.1 4.5
# 5 DAV  2024-01-01 04:00:00 2024 1     1   4    lun\\.  Weekday Winter 65.8 0.7
# 6 DAV  2024-01-01 05:00:00 2024 1     1   5    lun\\.  Weekday Winter 67.1 0.7
#   PM10 NOX TEMP PREC RAD  SO2 PM2.5 EC CPC
# 1 1.2  1.9 -2.2 0    -0.6 NA  NA    NA NA
# 2 1.5  2.1 -2.8 0    -0.7 NA  NA    NA NA
# 3 2.2  3.7 -3.3 0    -0.7 NA  NA    NA NA
# 4 3.0  4.6 -4.2 0    -1.1 NA  NA    NA NA
# 5 0.2  0.7 -5.2 0    -1.3 NA  NA    NA NA
# 6 0.4  0.7 -5.6 0    -0.8 NA  NA    NA NA

# %% [markdown]
# ### Overall mean differences differences

# %%
# Environmental variables to test in DAVOS
environmental_variables <- c("O3", "NO2", "PM10", "NOX", "TEMP", "PREC", "RAD")

# Loop through the variables
for (var in environmental_variables) {
  
  # Filter data for weekends and weekdays
  O3_weekends_DAV <- all_data_lf %>%
    filter(site == "DAV", variable == var & daytype == "Weekend")
  
  O3_weekdays_DAV <- all_data_lf %>%
    filter(site == "DAV", variable == var & daytype == "Weekday")
  
  # Perform t-test
  test_result <- t.test(O3_weekends_DAV$value, O3_weekdays_DAV$value)
  
  # Print the results
  cat("T-test results for", var, ":\n")
  print(test_result)
  cat("\n")  # Adds a blank line for better readability
}
# Out:
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664

# %%
# Environmental variables to test in DAVOS, monthly details
environmental_variables <- c("O3", "NO2", "PM10", "NOX", "TEMP", "PREC", "RAD")

# Loop through the variables
for (var in environmental_variables) {
  
   for (i in seq(1,12, by=1)){
  
      # Filter data for weekends and weekdays
      O3_weekends_DAV <- all_data_lf %>%
        filter(site == "DAV", variable == var & daytype == "Weekend")
      
      O3_weekdays_DAV <- all_data_lf %>%
        filter(site == "DAV", variable == var & daytype == "Weekday")
      
      # Perform t-test
      test_result <- t.test(O3_weekends_DAV$value, O3_weekdays_DAV$value)
      
      # Print the results
      cat("T-test results for", var, "during month ", i, ":\n")
      print(test_result)
      cat("\n")  # Adds a blank line for better readability
    }
}
# Out:
# T-test results for O3 during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for O3 during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 6.1738, df = 4824.1, p-value = 7.214e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.553113 2.998439
# sample estimates:
# mean of x mean of y
#  67.80048  65.52470
#
#
# T-test results for NO2 during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for NO2 during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.9966, df = 5941.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.3867356 -0.2599240
# sample estimates:
# mean of x mean of y
#  1.717909  2.041238
#
#
# T-test results for PM10 during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for PM10 during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.4787, df = 5158.5, p-value = 0.1393
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1631074  1.1644710
# sample estimates:
# mean of x mean of y
#  5.493590  4.992908
#
#
# T-test results for NOX during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for NOX during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -9.7055, df = 6114.3, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4417063 -0.2932555
# sample estimates:
# mean of x mean of y
#  1.925561  2.293042
#
#
# T-test results for TEMP during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for TEMP during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 1.034, df = 4526.7, p-value = 0.3012
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.1609561  0.5201910
# sample estimates:
# mean of x mean of y
#  5.819471  5.639854
#
#
# T-test results for PREC during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for PREC during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = -0.27847, df = 4433.2, p-value = 0.7807
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02661778  0.01999656
# sample estimates:
#  mean of x  mean of y
# 0.09651442 0.09982504
#
#
# T-test results for RAD during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664
#
#
# T-test results for RAD during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_DAV$value and O3_weekdays_DAV$value
# t = 0.043503, df = 4619.8, p-value = 0.9653
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.38162  10.85282
# sample estimates:
# mean of x mean of y
#  144.2020  143.9664

# %%
# Environmental variables to test in BASEL tested every months
environmental_variables <- c("O3", "NO2", "PM10", "NOX", "TEMP", "PREC", "RAD", "SO2", "PM2.5", "EC", "CPC")

# Loop through the variables
for (var in environmental_variables) {
    for (i in seq(1,12, by=1)){
  
      # Filter data for weekends and weekdays
      O3_weekends_BAS <- all_data_lf %>%
        filter(site == "BAS", variable == var & daytype == "Weekend")
      
      O3_weekdays_BAS <- all_data_lf %>%
        filter(site == "BAS", variable == var & daytype == "Weekday")
      
      # Perform t-test
      test_result <- t.test(O3_weekends_BAS$value, O3_weekdays_BAS$value)
      
      # Print the results
      cat("T-test results for", var, ":\n")
      print(test_result)
      cat("\n")  # Adds a blank line for better readability
    }
}
# Out:
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for O3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.3565, df = 4700.8, p-value = 0.175
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.418884  2.300452
# sample estimates:
# mean of x mean of y
#  51.20061  50.25982
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for NO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.2736, df = 5543.1, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.527312 -1.645253
# sample estimates:
# mean of x mean of y
#  11.04953  13.13582
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for PM10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.3714, df = 4419.7, p-value = 0.1703
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6320214  0.1117384
# sample estimates:
# mean of x mean of y
#  11.00636  11.26651
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for NOX :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -13.311, df = 6995.2, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.565296 -3.393238
# sample estimates:
# mean of x mean of y
#  12.65014  16.62941
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for TEMP :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4977, df = 4388.4, p-value = 0.1343
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.63268153  0.08467128
# sample estimates:
# mean of x mean of y
#  11.99804  12.27204
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for PREC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.6469, df = 6252.4, p-value = 0.09963
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.041400315  0.003597746
# sample estimates:
#  mean of x  mean of y
# 0.07876603 0.09766731
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for RAD :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.57411, df = 4672.2, p-value = 0.5659
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.105993 12.991351
# sample estimates:
# mean of x mean of y
#  136.8868  133.9441
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for SO2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5297, df = 5946.7, p-value = 0.01144
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.061925625 -0.007851545
# sample estimates:
# mean of x mean of y
# 0.4801378 0.5150264
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for PM2.5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.8555, df = 4411.6, p-value = 0.004317
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.1441719 0.7758108
# sample estimates:
# mean of x mean of y
#  8.079408  7.619417
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for EC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.49133, df = 4894.8, p-value = 0.6232
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.015742788  0.009433129
# sample estimates:
# mean of x mean of y
# 0.3178021 0.3209569
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661
#
#
# T-test results for CPC :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.4858, df = 4954.8, p-value = 7.43e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -658.2555 -257.8735
# sample estimates:
# mean of x mean of y
#  6585.597  7043.661

# %%
# Environmental variables to test in BASEL tested every months
environmental_variables <- c("O3", "NO2", "PM10", "NOX", "TEMP", "PREC", "RAD", "SO2", "PM2.5", "EC", "CPC")

# Loop through the variables
for (var in environmental_variables) {
    for (i in seq(1,12, by=1)){
  
      # Filter data for weekends and weekdays
      O3_weekends_BAS <- all_data_lf %>%
        filter(month==i, site == "BAS", variable == var & daytype == "Weekend")
      
      O3_weekdays_BAS <- all_data_lf %>%
        filter(month==i, site == "BAS", variable == var & daytype == "Weekday")
      
      # Perform t-test
      test_result <- t.test(O3_weekends_BAS$value, O3_weekdays_BAS$value)
      
      # Print the results
      cat("T-test results for", var, "during month ", i, ":\n")
      print(test_result)
      cat("\n")  # Adds a blank line for better readability
    }
}
# Out:
# T-test results for O3 during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -6.8298, df = 697.9, p-value = 1.852e-11
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -12.658267  -7.005508
# sample estimates:
# mean of x mean of y
#  27.08542  36.91730
#
#
# T-test results for O3 during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.29662, df = 415.11, p-value = 0.7669
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.939042  3.983672
# sample estimates:
# mean of x mean of y
#  44.78646  44.26414
#
#
# T-test results for O3 during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.72008, df = 459.48, p-value = 0.4718
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -5.057163  2.344862
# sample estimates:
# mean of x mean of y
#  50.99375  52.34990
#
#
# T-test results for O3 during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 4.1525, df = 317.35, p-value = 4.231e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#   4.219226 11.817476
# sample estimates:
# mean of x mean of y
#  73.73854  65.72019
#
#
# T-test results for O3 during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.91394, df = 280.46, p-value = 0.3615
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.444996  6.683117
# sample estimates:
# mean of x mean of y
#  67.15833  65.03927
#
#
# T-test results for O3 during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.7704, df = 642.32, p-value = 2.278e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -11.560926  -4.818516
# sample estimates:
# mean of x mean of y
#  59.44333  67.63305
#
#
# T-test results for O3 during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.944, df = 344.77, p-value = 0.05271
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.05014854  8.57384172
# sample estimates:
# mean of x mean of y
#  68.91094  64.64909
#
#
# T-test results for O3 during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.55664, df = 465.48, p-value = 0.578
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -5.755111  3.214349
# sample estimates:
# mean of x mean of y
#  72.46435  73.73473
#
#
# T-test results for O3 during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.4926, df = 346.57, p-value = 0.01315
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.173278 9.951980
# sample estimates:
# mean of x mean of y
#  60.91343  55.35080
#
#
# T-test results for O3 during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.57048, df = 445.19, p-value = 0.5686
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3.669644  2.018508
# sample estimates:
# mean of x mean of y
#  25.05625  25.88182
#
#
# T-test results for O3 during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.057, df = 587.5, p-value = 0.291
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.590913  1.378424
# sample estimates:
# mean of x mean of y
#  23.29535  24.90159
#
#
# T-test results for O3 during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 5.4527, df = 316.83, p-value = 9.999e-08
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#   6.767448 14.408144
# sample estimates:
# mean of x mean of y
#  37.74255  27.15476
#
#
# T-test results for NO2 during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.383, df = 453.84, p-value = 0.1673
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6668776  3.8350584
# sample estimates:
# mean of x mean of y
#  24.35312  22.76903
#
#
# T-test results for NO2 during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -6.2951, df = 571.68, p-value = 6.122e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -6.812802 -3.572511
# sample estimates:
# mean of x mean of y
#  11.73802  16.93068
#
#
# T-test results for NO2 during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.5305, df = 446.58, p-value = 0.1266
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.6553145  0.3302847
# sample estimates:
# mean of x mean of y
#  13.18500  14.34751
#
#
# T-test results for NO2 during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.2657, df = 532.02, p-value = 2.359e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3.308923 -1.222232
# sample estimates:
# mean of x mean of y
#  8.510938 10.776515
#
#
# T-test results for NO2 during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.1098, df = 476.43, p-value = 0.9126
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.7821834  0.6993955
# sample estimates:
# mean of x mean of y
#  7.533333  7.574727
#
#
# T-test results for NO2 during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.5974, df = 574.8, p-value = 3.372e-08
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.674580 -1.285138
# sample estimates:
# mean of x mean of y
#  6.336250  8.316109
#
#
# T-test results for NO2 during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -3.6059, df = 466.4, p-value = 0.0003446
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.9273012 -0.5676496
# sample estimates:
# mean of x mean of y
#  5.611979  6.859455
#
#
# T-test results for NO2 during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -6.7509, df = 594.64, p-value = 3.498e-11
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3.012136 -1.654524
# sample estimates:
# mean of x mean of y
#  5.288426  7.621756
#
#
# T-test results for NO2 during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.8018, df = 689.55, p-value = 1.929e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.835311 -1.189586
# sample estimates:
# mean of x mean of y
#  7.007870  9.020319
#
#
# T-test results for NO2 during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.8006, df = 443.64, p-value = 1.258e-08
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.313122 -2.130061
# sample estimates:
# mean of x mean of y
#  12.37187  15.59347
#
#
# T-test results for NO2 during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.4668, df = 617.9, p-value = 0.0139
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.7872866 -0.3164306
# sample estimates:
# mean of x mean of y
#  16.70093  18.25279
#
#
# T-test results for NO2 during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.8601, df = 376.3, p-value = 1.726e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -6.216395 -2.635201
# sample estimates:
# mean of x mean of y
#   15.2367   19.6625
#
#
# T-test results for PM10 during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 4.3183, df = 364.85, p-value = 2.029e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  2.467042 6.592786
# sample estimates:
# mean of x mean of y
#  20.59531  16.06540
#
#
# T-test results for PM10 during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -6.5403, df = 516.54, p-value = 1.478e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.058133 -2.183335
# sample estimates:
# mean of x mean of y
#   7.25625  10.37698
#
#
# T-test results for PM10 during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 3.8863, df = 293.21, p-value = 0.0001259
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.837497 5.608019
# sample estimates:
# mean of x mean of y
#  14.87375  11.15099
#
#
# T-test results for PM10 during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.5613, df = 505.01, p-value = 0.1191
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.072210  0.237077
# sample estimates:
# mean of x mean of y
#  9.195312 10.112879
#
#
# T-test results for PM10 during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.54005, df = 522.89, p-value = 0.5894
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.9731041  0.5534483
# sample estimates:
# mean of x mean of y
#  8.267708  8.477536
#
#
# T-test results for PM10 during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.5839, df = 387.74, p-value = 4.431e-08
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3.455190 -1.655643
# sample estimates:
# mean of x mean of y
#  9.225833 11.781250
#
#
# T-test results for PM10 during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -3.3722, df = 392.45, p-value = 0.0008199
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.0171620 -0.5313434
# sample estimates:
# mean of x mean of y
#  11.07031  12.34457
#
#
# T-test results for PM10 during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.54394, df = 297.25, p-value = 0.5869
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.7085132  1.2497715
# sample estimates:
# mean of x mean of y
#  12.13565  11.86502
#
#
# T-test results for PM10 during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.9979, df = 411.28, p-value = 0.04638
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.01367481 1.68500243
# sample estimates:
# mean of x mean of y
#  9.445370  8.596032
#
#
# T-test results for PM10 during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.299, df = 653.18, p-value = 1.977e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.9182150 -0.7153267
# sample estimates:
# mean of x mean of y
#  8.892188 10.208958
#
#
# T-test results for PM10 during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.38904, df = 705.53, p-value = 0.6974
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.8364782  1.2498983
# sample estimates:
# mean of x mean of y
#  11.70651  11.49980
#
#
# T-test results for PM10 during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -6.7954, df = 357.02, p-value = 4.541e-11
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.617682 -2.544808
# sample estimates:
# mean of x mean of y
#  8.814894 12.396139
#
#
# T-test results for NOX during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.0509, df = 621.51, p-value = 0.0407
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -6.3212460 -0.1370987
# sample estimates:
# mean of x mean of y
#  27.73021  30.95938
#
#
# T-test results for NOX during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -6.2034, df = 607.31, p-value = 1.022e-09
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -8.567295 -4.447180
# sample estimates:
# mean of x mean of y
#  13.41667  19.92390
#
#
# T-test results for NOX during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.1823, df = 553.99, p-value = 0.02951
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3.8618192 -0.2030317
# sample estimates:
# mean of x mean of y
#  14.83000  16.86243
#
#
# T-test results for NOX during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.5701, df = 592.59, p-value = 5.935e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.079238 -1.627012
# sample estimates:
# mean of x mean of y
#  9.448958 12.302083
#
#
# T-test results for NOX during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.36583, df = 523.61, p-value = 0.7146
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.0396691  0.7132448
# sample estimates:
# mean of x mean of y
#  8.583333  8.746545
#
#
# T-test results for NOX during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -6.1347, df = 663.22, p-value = 1.467e-09
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3.517370 -1.811678
# sample estimates:
# mean of x mean of y
#  7.171250  9.835774
#
#
# T-test results for NOX during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.2647, df = 569.76, p-value = 2.343e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.5959941 -0.9588165
# sample estimates:
# mean of x mean of y
#  6.248958  8.026364
#
#
# T-test results for NOX during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -7.1536, df = 683.57, p-value = 2.183e-12
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3.828092 -2.179252
# sample estimates:
# mean of x mean of y
#  5.717130  8.720802
#
#
# T-test results for NOX during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.2346, df = 715.92, p-value = 2.175e-07
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.103778 -1.865091
# sample estimates:
# mean of x mean of y
#  7.793056 10.777490
#
#
# T-test results for NOX during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -8.6254, df = 668.62, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -7.802409 -4.908784
# sample estimates:
# mean of x mean of y
#  14.22135  20.57695
#
#
# T-test results for NOX during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -6.7001, df = 705.92, p-value = 4.258e-11
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -8.411640 -4.599119
# sample estimates:
# mean of x mean of y
#  20.09860  26.60398
#
#
# T-test results for NOX during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.9065, df = 479.44, p-value = 6.627e-09
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -10.944466  -5.480416
# sample estimates:
# mean of x mean of y
#  18.06117  26.27361
#
#
# T-test results for TEMP during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -8.8528, df = 416.72, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -4.214843 -2.683209
# sample estimates:
# mean of x mean of y
# 0.5151042 3.9641304
#
#
# T-test results for TEMP during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.3317, df = 331.55, p-value = 1.963e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.5144990 -0.5685367
# sample estimates:
# mean of x mean of y
#  7.403125  8.444643
#
#
# T-test results for TEMP during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.51658, df = 597.98, p-value = 0.6056
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6455724  0.3766835
# sample estimates:
# mean of x mean of y
#  9.201667  9.336111
#
#
# T-test results for TEMP during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 6.4349, df = 271.44, p-value = 5.564e-10
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  2.558703 4.814498
# sample estimates:
# mean of x mean of y
#  13.75365  10.06705
#
#
# T-test results for TEMP during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 3.4034, df = 275.61, p-value = 0.0007643
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.5003619 1.8733700
# sample estimates:
# mean of x mean of y
#  15.81458  14.62772
#
#
# T-test results for TEMP during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -3.9572, df = 567.2, p-value = 8.544e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.8835234 -0.6339766
# sample estimates:
# mean of x mean of y
#  17.82292  19.08167
#
#
# T-test results for TEMP during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.9326, df = 356.02, p-value = 0.05408
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.41438066  0.01234262
# sample estimates:
# mean of x mean of y
#  20.47760  21.17862
#
#
# T-test results for TEMP during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.35325, df = 421.44, p-value = 0.7241
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.6087809  0.8755317
# sample estimates:
# mean of x mean of y
#  22.26481  22.13144
#
#
# T-test results for TEMP during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.57973, df = 323.79, p-value = 0.5625
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.1573711  0.6305192
# sample estimates:
# mean of x mean of y
#  15.43102  15.69444
#
#
# T-test results for TEMP during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.8579, df = 332.96, p-value = 1.126e-08
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.7715723 -0.8808733
# sample estimates:
# mean of x mean of y
#  11.94896  13.27518
#
#
# T-test results for TEMP during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.1028, df = 436.41, p-value = 0.03606
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.12191077 -0.03787759
# sample estimates:
# mean of x mean of y
#  5.812963  6.392857
#
#
# T-test results for TEMP during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.55097, df = 428.39, p-value = 0.5819
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.5835127  0.3279993
# sample estimates:
# mean of x mean of y
#  2.962963  3.090720
#
#
# T-test results for PREC during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.8247, df = 674.45, p-value = 1.735e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.14436065 -0.06084768
# sample estimates:
# mean of x mean of y
# 0.0265625 0.1291667
#
#
# T-test results for PREC during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.88296, df = 272.76, p-value = 0.378
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.01884757  0.04950233
# sample estimates:
#  mean of x  mean of y
# 0.05520833 0.03988095
#
#
# T-test results for PREC during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.28496, df = 586.16, p-value = 0.7758
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.06796130  0.05073908
# sample estimates:
#  mean of x  mean of y
# 0.09416667 0.10277778
#
#
# T-test results for PREC during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.305, df = 431.49, p-value = 0.1926
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.06288963  0.01270024
# sample estimates:
#  mean of x  mean of y
# 0.04270833 0.06780303
#
#
# T-test results for PREC during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.9994, df = 525.37, p-value = 0.002834
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.35133600 -0.07324733
# sample estimates:
#  mean of x  mean of y
# 0.05416667 0.26645833
#
#
# T-test results for PREC during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.8425, df = 549.66, p-value = 0.06595
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.006103034  0.190686368
# sample estimates:
# mean of x mean of y
# 0.1679167 0.0756250
#
#
# T-test results for PREC during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.2295, df = 211, p-value = 0.2203
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.05813395  0.25084228
# sample estimates:
#  mean of x  mean of y
# 0.15468750 0.05833333
#
#
# T-test results for PREC during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.3593, df = 303.94, p-value = 0.01894
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.007494161 0.082825704
# sample estimates:
#  mean of x  mean of y
# 0.06712963 0.02196970
#
#
# T-test results for PREC during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.7871, df = 524, p-value = 0.0745
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.113294339  0.005357831
# sample estimates:
# mean of x mean of y
# 0.0750000 0.1289683
#
#
# T-test results for PREC during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.8496, df = 738.5, p-value = 0.004499
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.15065010 -0.02774664
# sample estimates:
#  mean of x  mean of y
# 0.04322917 0.13242754
#
#
# T-test results for PREC during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.001, df = 505.5, p-value = 7.881e-07
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.14324696 -0.06244087
# sample estimates:
#   mean of x   mean of y
# 0.002314815 0.105158730
#
#
# T-test results for PREC during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.3528, df = 264.23, p-value = 0.01937
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.01384785 0.15593329
# sample estimates:
#  mean of x  mean of y
# 0.13981481 0.05492424
#
#
# T-test results for RAD during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.9339, df = 271.67, p-value = 0.05417
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.2912021 32.5992184
# sample estimates:
# mean of x mean of y
#  55.77865  39.62464
#
#
# T-test results for RAD during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.097, df = 300.7, p-value = 0.2735
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -9.396366 33.069828
# sample estimates:
# mean of x mean of y
#  77.57760  65.74087
#
#
# T-test results for RAD during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.0634, df = 552.87, p-value = 0.2881
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -42.75135  12.72028
# sample estimates:
# mean of x mean of y
#  110.0779  125.0935
#
#
# T-test results for RAD during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.451, df = 288.24, p-value = 0.01484
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  10.11719 92.60468
# sample estimates:
# mean of x mean of y
#  198.5734  147.2125
#
#
# T-test results for RAD during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.3508, df = 300.22, p-value = 0.01938
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#   8.84518 99.75500
# sample estimates:
# mean of x mean of y
#  238.7396  184.4395
#
#
# T-test results for RAD during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.3743, df = 612.93, p-value = 1.432e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -121.54322  -46.22386
# sample estimates:
# mean of x mean of y
#  160.4854  244.3690
#
#
# T-test results for RAD during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.8774, df = 348.66, p-value = 0.3809
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -68.55371  26.25774
# sample estimates:
# mean of x mean of y
#   231.537   252.685
#
#
# T-test results for RAD during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.125, df = 428.73, p-value = 0.2612
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -71.67887  19.49461
# sample estimates:
# mean of x mean of y
#  228.5537  254.6458
#
#
# T-test results for RAD during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.8978, df = 360.25, p-value = 0.05852
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.249661 70.221487
# sample estimates:
# mean of x mean of y
#  163.4861  129.0002
#
#
# T-test results for RAD during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.093, df = 320.87, p-value = 0.2752
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -9.969249 34.892664
# sample estimates:
# mean of x mean of y
#  89.14323  76.68152
#
#
# T-test results for RAD during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.89156, df = 374.6, p-value = 0.3732
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -9.38430 24.95361
# sample estimates:
# mean of x mean of y
#  59.47176  51.68710
#
#
# T-test results for RAD during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.092415, df = 406.29, p-value = 0.9264
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -12.58499  11.45485
# sample estimates:
# mean of x mean of y
#  37.35463  37.91970
#
#
# T-test results for SO2 during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -9.07, df = 722.02, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.445037 -0.286657
# sample estimates:
# mean of x mean of y
# 0.4833333 0.8491803
#
#
# T-test results for SO2 during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.5982, df = 477.86, p-value = 0.009661
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.24985419 -0.03467437
# sample estimates:
# mean of x mean of y
# 0.5583333 0.7005976
#
#
# T-test results for SO2 during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.9992, df = 702.77, p-value = 0.002803
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.22574811 -0.04711968
# sample estimates:
# mean of x mean of y
# 0.5162500 0.6526839
#
#
# T-test results for SO2 during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 5.8714, df = 219.17, p-value = 1.586e-08
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.2882348 0.5795072
# sample estimates:
# mean of x mean of y
#  0.850000  0.416129
#
#
# T-test results for SO2 during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 3.734, df = 549.59, p-value = 0.0002081
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.07117142 0.22916570
# sample estimates:
# mean of x mean of y
# 0.4848958 0.3347273
#
#
# T-test results for SO2 during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.996, df = 708.02, p-value = 3.223e-09
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.2197750 -0.1113512
# sample estimates:
# mean of x mean of y
# 0.2695833 0.4351464
#
#
# T-test results for SO2 during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.5819, df = 281.02, p-value = 0.1148
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02061023  0.18931856
# sample estimates:
# mean of x mean of y
# 0.4963542 0.4120000
#
#
# T-test results for SO2 during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.3207, df = 698.86, p-value = 0.02059
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.19258241 -0.01606192
# sample estimates:
# mean of x mean of y
# 0.3384259 0.4427481
#
#
# T-test results for SO2 during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.4637, df = 267.3, p-value = 0.01438
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.02171938 0.19456733
# sample estimates:
# mean of x mean of y
# 0.3726852 0.2645418
#
#
# T-test results for SO2 during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.90156, df = 573.12, p-value = 0.3677
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.07531218  0.02792486
# sample estimates:
# mean of x mean of y
# 0.4302083 0.4539020
#
#
# T-test results for SO2 during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.7681, df = 629.65, p-value = 0.07753
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.19827611  0.01039523
# sample estimates:
# mean of x mean of y
# 0.4786047 0.5725451
#
#
# T-test results for SO2 during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.066, df = 510.2, p-value = 0.03933
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.174516502 -0.004389037
# sample estimates:
# mean of x mean of y
# 0.5595745 0.6490272
#
#
# T-test results for PM2.5 during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 5.0857, df = 354.56, p-value = 5.948e-07
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  3.229339 7.301865
# sample estimates:
# mean of x mean of y
#  18.76615  13.50054
#
#
# T-test results for PM2.5 during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.80073, df = 395.95, p-value = 0.4238
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.297113  0.546303
# sample estimates:
# mean of x mean of y
#  6.604687  6.980093
#
#
# T-test results for PM2.5 during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 4.0964, df = 434.14, p-value = 5.008e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.105966 3.146117
# sample estimates:
# mean of x mean of y
#  8.996667  6.870625
#
#
# T-test results for PM2.5 during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -3.2597, df = 462.67, p-value = 0.001198
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1.4370982 -0.3560836
# sample estimates:
# mean of x mean of y
#  4.620833  5.517424
#
#
# T-test results for PM2.5 during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.9056, df = 376.11, p-value = 0.05746
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.01526731  0.97426352
# sample estimates:
# mean of x mean of y
#  4.704688  4.225189
#
#
# T-test results for PM2.5 during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -3.987, df = 387.27, p-value = 7.997e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2.0972170 -0.7119496
# sample estimates:
# mean of x mean of y
#  6.335417  7.740000
#
#
# T-test results for PM2.5 during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.26074, df = 321.35, p-value = 0.7945
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.4052245  0.5290469
# sample estimates:
# mean of x mean of y
#  5.567708  5.505797
#
#
# T-test results for PM2.5 during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.7841, df = 290.83, p-value = 0.07545
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.06957238  1.41814107
# sample estimates:
# mean of x mean of y
#  7.521296  6.847012
#
#
# T-test results for PM2.5 during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.0062, df = 346.23, p-value = 0.04562
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.01504891 1.52046034
# sample estimates:
# mean of x mean of y
#  6.533796  5.766042
#
#
# T-test results for PM2.5 during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -0.50926, df = 616.65, p-value = 0.6107
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.5888123  0.3463123
# sample estimates:
# mean of x mean of y
#  6.453125  6.574375
#
#
# T-test results for PM2.5 during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 4.7397, df = 510.25, p-value = 2.78e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.251387 3.023252
# sample estimates:
# mean of x mean of y
# 11.960930  9.823611
#
#
# T-test results for PM2.5 during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.5539, df = 316.18, p-value = 7.527e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -3.869965 -1.534824
# sample estimates:
# mean of x mean of y
#  8.909574 11.611969
#
#
# T-test results for EC during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.7935, df = 416.67, p-value = 0.07362
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.006734615  0.147027655
# sample estimates:
# mean of x mean of y
# 0.6666667 0.5965201
#
#
# T-test results for EC during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -3.6755, df = 443.46, p-value = 0.0002664
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.11422784 -0.03463128
# sample estimates:
# mean of x mean of y
# 0.2890625 0.3634921
#
#
# T-test results for EC during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.285, df = 362.68, p-value = 0.02289
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.00649662 0.08671767
# sample estimates:
# mean of x mean of y
# 0.3329167 0.2863095
#
#
# T-test results for EC during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.7472, df = 321.16, p-value = 0.08155
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.003185477  0.053753659
# sample estimates:
# mean of x mean of y
# 0.2385417 0.2132576
#
#
# T-test results for EC during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 3.7649, df = 311.07, p-value = 0.0001992
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.01876655 0.05985664
# sample estimates:
# mean of x mean of y
# 0.2083333 0.1690217
#
#
# T-test results for EC during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -3.2983, df = 393.85, p-value = 0.001061
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.05552962 -0.01405372
# sample estimates:
# mean of x mean of y
# 0.1845833 0.2193750
#
#
# T-test results for EC during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.7722, df = 448.24, p-value = 0.005799
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.056151142 -0.009564437
# sample estimates:
# mean of x mean of y
# 0.2015625 0.2344203
#
#
# T-test results for EC during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 1.9173, df = 321.3, p-value = 0.05609
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.0006932931  0.0537773658
# sample estimates:
# mean of x mean of y
# 0.2527778 0.2262357
#
#
# T-test results for EC during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 2.5734, df = 352.95, p-value = 0.01048
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  0.009588904 0.071760302
# sample estimates:
# mean of x mean of y
# 0.2805556 0.2398810
#
#
# T-test results for EC during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.1204, df = 483.13, p-value = 0.2631
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.04302593  0.01177593
# sample estimates:
# mean of x mean of y
#  0.346875  0.362500
#
#
# T-test results for EC during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.74026, df = 475.91, p-value = 0.4595
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.02646611  0.05846062
# sample estimates:
# mean of x mean of y
# 0.4705607 0.4545635
#
#
# T-test results for EC during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.5866, df = 366.01, p-value = 6.197e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.16378983 -0.06548808
# sample estimates:
# mean of x mean of y
# 0.3670213 0.4816602
#
#
# T-test results for CPC during month  1 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.5602, df = 381.43, p-value = 0.1195
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1496.5539   172.2867
# sample estimates:
# mean of x mean of y
#  7278.197  7940.330
#
#
# T-test results for CPC during month  2 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.341, df = 413.08, p-value = 0.01971
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1563.374  -136.221
# sample estimates:
# mean of x mean of y
#  6150.866  7000.663
#
#
# T-test results for CPC during month  3 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -1.4667, df = 436.57, p-value = 0.1432
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1145.6974   166.4948
# sample estimates:
# mean of x mean of y
#  6664.502  7154.103
#
#
# T-test results for CPC during month  4 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 5.0938, df = 341.55, p-value = 5.818e-07
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1194.694 2697.745
# sample estimates:
# mean of x mean of y
#  8588.273  6642.053
#
#
# T-test results for CPC during month  5 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 5.3576, df = 340.72, p-value = 1.556e-07
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1003.886 2168.607
# sample estimates:
# mean of x mean of y
#  7337.514  5751.267
#
#
# T-test results for CPC during month  6 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.7586, df = 583.6, p-value = 2.461e-06
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2449.701 -1018.321
# sample estimates:
# mean of x mean of y
#  6290.290  8024.301
#
#
# T-test results for CPC during month  7 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.81039, df = 285.64, p-value = 0.4184
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -446.2724 1070.9444
# sample estimates:
# mean of x mean of y
#  7141.772  6829.436
#
#
# T-test results for CPC during month  8 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -2.4163, df = 341.78, p-value = 0.0162
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1678.0187  -172.0217
# sample estimates:
# mean of x mean of y
#  6135.327  7060.348
#
#
# T-test results for CPC during month  9 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = 0.38192, df = 564.35, p-value = 0.7027
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -436.0442  646.5458
# sample estimates:
# mean of x mean of y
#  6098.878  5993.627
#
#
# T-test results for CPC during month  10 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -3.779, df = 391.17, p-value = 0.000182
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -1751.0246  -552.5753
# sample estimates:
# mean of x mean of y
#  6268.211  7420.011
#
#
# T-test results for CPC during month  11 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -5.6567, df = 598.76, p-value = 2.392e-08
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2486.751 -1205.020
# sample estimates:
# mean of x mean of y
#  5645.772  7491.657
#
#
# T-test results for CPC during month  12 :
#
# 	Welch Two Sample t-test
#
# data:  O3_weekends_BAS$value and O3_weekdays_BAS$value
# t = -4.2905, df = 426.22, p-value = 2.208e-05
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -2138.6474  -794.7887
# sample estimates:
# mean of x mean of y
#  5810.657  7277.375
