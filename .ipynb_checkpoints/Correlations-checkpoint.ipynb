# %% [markdown]
# # Correlations

# %%
library(tidyverse)
library(tidyr)
library(dplyr)
library(ggplot2)
library(readxl)
library(openxlsx)
library(lattice)
# Out:
# -- Attaching core tidyverse packages ---------------------------------------------------------------- tidyverse 2.0.0 --
# v dplyr     1.1.2     v readr     2.1.4
# v forcats   1.0.0     v stringr   1.5.1
# v ggplot2   3.4.2     v tibble    3.2.1
# v lubridate 1.9.2     v tidyr     1.3.0
# v purrr     1.0.1
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ## importing data

# %%
# Read a CSV file into a data frame
df <- read.csv("Data/All_dat_df.csv")

# %%
head(df)
# Out:
#   site datetime            year month day hour dayofwk daytype season O3   ...
# 1 DAV  2024-01-01 00:00:00 2024 1     1   0    Mon     Weekday Winter 57.7 ...
# 2 DAV  2024-01-01 01:00:00 2024 1     1   1    Mon     Weekday Winter 55.2 ...
# 3 DAV  2024-01-01 02:00:00 2024 1     1   2    Mon     Weekday Winter 49.9 ...
# 4 DAV  2024-01-01 03:00:00 2024 1     1   3    Mon     Weekday Winter 52.1 ...
# 5 DAV  2024-01-01 04:00:00 2024 1     1   4    Mon     Weekday Winter 65.8 ...
# 6 DAV  2024-01-01 05:00:00 2024 1     1   5    Mon     Weekday Winter 67.1 ...
#   NOX TEMP PREC RAD  SO2 PM2.5 EC CPC avg_wind_speed avg_wind_direction
# 1 1.9 -2.2 0    -0.6 NA  NA    NA NA  1.0980000       36.25794
# 2 2.1 -2.8 0    -0.7 NA  NA    NA NA  0.9216667       40.71351
# 3 3.7 -3.3 0    -0.7 NA  NA    NA NA  0.6716667      150.12313
# 4 4.6 -4.2 0    -1.1 NA  NA    NA NA  0.5250000       40.87731
# 5 0.7 -5.2 0    -1.3 NA  NA    NA NA  1.4700000      186.90946
# 6 0.7 -5.6 0    -0.8 NA  NA    NA NA  1.9350000      184.88936

# %%
# Access column names
colnames(df)
variables <- c('O3','NO2','PM10','NOX','TEMP','PREC','RAD','SO2','PM2.5','EC','CPC','avg_wind_speed','avg_wind_direction')
# Out:
#  [1] "site"               "datetime"           "year"
#  [4] "month"              "day"                "hour"
#  [7] "dayofwk"            "daytype"            "season"
# [10] "O3"                 "NO2"                "PM10"
# [13] "NOX"                "TEMP"               "PREC"
# [16] "RAD"                "SO2"                "PM2.5"
# [19] "EC"                 "CPC"                "avg_wind_speed"
# [22] "avg_wind_direction"

# %%
lf <- pivot_longer(df, all_of(variables), names_to = "variable", values_to = "value")
daily.max <- lf %>%
  group_by(site, year, month, day, season, variable) %>%
  summarize(value = max(value, na.rm=TRUE), .groups = "drop") %>%
  pivot_wider(names_from = variable, values_from = value)
# Out:
# Warning message:
# "There were 1487 warnings in `summarize()`.
# The first warning was:
# i In argument: `value = max(value, na.rm = TRUE)`.
# i In group 170: `site = "BAS"`, `year = 2024`, `month = 1`, `day = 14`, `season = "Winter"`, `variable = "CPC"`.
# Caused by warning in `max()`:
# ! aucun argument pour max ; -Inf est renvoyé
# i Run `dplyr::last_dplyr_warnings()` to see the 1486 remaining warnings."

# %%
head(daily.max)
# Out:
#   site year month day season CPC     EC  NO2  NOX  O3   PM10 PM2.5 PREC RAD
# 1 BAS  2024 1     1   Winter 16766.3 0.8 32.6 34.7 71.7 35.8 25.2  1.4  191.0
# 2 BAS  2024 1     2   Winter 10805.3 0.4 22.1 23.3 85.3 10.3  6.7  2.0   79.2
# 3 BAS  2024 1     3   Winter  2405.6 0.1  2.1  2.9 84.1  4.1  2.0  2.6  276.7
# 4 BAS  2024 1     4   Winter 14598.9 0.8 32.8 33.2 83.1 12.9  7.8  0.3  245.8
# 5 BAS  2024 1     5   Winter 17940.7 1.7 45.1 99.2 33.1 24.7 15.7  0.5   66.7
# 6 BAS  2024 1     6   Winter  8110.8 0.7 14.2 14.3 54.1 13.8 11.3  0.5  114.8
#   SO2 TEMP avg_wind_direction avg_wind_speed
# 1 2.2  8.3 267.4726           4.333333
# 2 4.5 12.4 242.9949           8.133333
# 3 0.2 13.7 257.8373           9.083333
# 4 1.2 10.2 265.1611           7.000000
# 5 2.9  6.3 237.9995           3.200000
# 6 0.6  6.2 294.1839           1.983333

# %% [markdown]
# ## Pairwise correlations plots for max daily values

# %%
Sys.setlocale("LC_TIME","C")
options(stringsAsFactors=FALSE)
theme_set(theme_bw()) # just my preference for plots
# Out:
# [1] "C"

# %%
daily.max %>%
  ggplot+
  facet_grid(site~season)+
  geom_point(aes(RAD, O3))
# Out:
# plot without title

# %%
daily.max %>%
  ggplot+
  facet_grid(site~season)+
  geom_point(aes(NO2, O3))
# Out:
# plot without title

# %% [markdown]
# ### Pairwise correlation coefficients for max daiy values

# %%
(cor.values.O3.NO2 <- daily.max %>% group_by(site, season) %>%
   summarize(correlation=cor(NO2, O3, use="pairwise.complete.obs"), .groups = "drop"))
# Out:
#   site season correlation
# 1 BAS  Autumn -0.30781192
# 2 BAS  Spring -0.14485469
# 3 BAS  Summer  0.31947457
# 4 BAS  Winter -0.29344664
# 5 DAV  Autumn  0.08346083
# 6 DAV  Spring  0.04540446
# 7 DAV  Summer  0.26180475
# 8 DAV  Winter -0.33688443

# %%
# Visualizing the correlation values
ggplot(cor.values.O3.NO2)+
  geom_col(aes(season, correlation))+
  #scale_y_continuous(limits=c(0,1), expand=expansion(mult=c(0, 0.1)))+
  facet_grid(.~site)
# Out:
# plot without title

# %%
(cor.values.O3.RAD <- daily.max %>% group_by(site, season) %>%
   summarize(correlation=cor(RAD, O3, use="pairwise.complete.obs"), .groups = "drop"))
# Out:
#   site season correlation
# 1 BAS  Autumn 0.48354037
# 2 BAS  Spring 0.64592159
# 3 BAS  Summer 0.40186378
# 4 BAS  Winter 0.06396458
# 5 DAV  Autumn 0.32536434
# 6 DAV  Spring 0.25759305
# 7 DAV  Summer 0.21184778
# 8 DAV  Winter 0.17405099

# %%
# Visualizing the correlation values
ggplot(cor.values.O3.RAD)+
  geom_col(aes(season, correlation))+
  #scale_y_continuous(limits=c(0,1), expand=expansion(mult=c(0, 0.1)))+
  facet_grid(.~site)
# Out:
# plot without title

# %%
pivot_longer(daily.max, cols = all_of(setdiff(variables, "O3")), names_to = "variable", values_to = "value") %>% # everything but ozone
  ggplot+
  facet_grid(site~variable, scale="free_x")+
  geom_point(aes(value, O3, group=season, color=season), shape=4)
# Out:
# plot without title

# %% [markdown]
# ### hourly corelation plots and coefficients

# %%
ggplot(df)+
  facet_grid(site~season)+
  geom_point(aes(O3, NO2))
# Out:
# Warning message:
# "Removed 103 rows containing missing values (`geom_point()`)."
# plot without title

# %% [markdown]
# ### Correlation matrix

# %%
CorrelationValue <- function(x, y, ...) {
  correlation <- cor(x, y, use="pairwise.complete.obs") 
  if(is.finite(correlation)) {
    cpl <- current.panel.limits()
    panel.text(mean(cpl$xlim), mean(cpl$ylim),
               bquote(italic(r)==.(sprintf("%.2f", correlation))),
               adj=c(0.5,0.5), col="blue")
  }
}

# %% [markdown]
# #### Daily max correlation matrix

# %%
daily.max %>%
  filter("DAV" == site) %>%
  with(splom(~cbind(O3, NO2, PM10, TEMP, PREC, RAD) | season,
      upper.panel = CorrelationValue,
      pch=4))
# Out:
# plot without title

# %%
daily.max %>%
  filter("BAS" == site) %>%
  with(splom(~cbind(CPC, EC, NO2, NOX, O3, PM10, PM2.5, PREC, RAD, SO2,	TEMP, avg_wind_direction, avg_wind_speed) | season,
      upper.panel = CorrelationValue,
      pch=4))
# Out:
# plot without title

# %% [markdown]
# #### Hourly data

# %%
df %>%
filter(grepl("BAS", site, fixed=TRUE)) %>%
with(splom(~cbind(O3, NO2, PM10, TEMP, PREC,RAD) | season,
      upper.panel = CorrelationValue,
      panel = panel.smoothScatter,
      pch=4, cex=.2, col="gray"))
# Out:
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# Warning message in KernSmooth::bkde2D(x, gridsize = nbin, bandwidth = bandwidth):
# "Binning grid too coarse for current (small) bandwidth: consider increasing 'gridsize'"
# plot without title

# %% [markdown]
# ### Lagged correlation

# %%
Lag <- function(pair, k) {
  tibble(lag=k, head(pair[,1],-k), tail(pair[,2],-k))
}


lagged <- df %>%
  group_by(site, season) %>%
  do(bind_rows(
    Lag(select(., RAD, O3), 1),
    Lag(select(., RAD, O3), 2),
    Lag(select(., RAD, O3), 3),
    Lag(select(., RAD, O3), 4),
    Lag(select(., RAD, O3), 5),
    Lag(select(., RAD, O3), 6)
  ))

# %%
head(lagged)
# Out:
#   site season lag RAD O3
# 1 BAS  Autumn 1   0.0 64.1
# 2 BAS  Autumn 1   0.0 54.5
# 3 BAS  Autumn 1   0.0 52.8
# 4 BAS  Autumn 1   0.0 43.6
# 5 BAS  Autumn 1   0.0 37.0
# 6 BAS  Autumn 1   1.3 32.3

# %%
RAD_O3_lagged_corr_plot <- ggplot(lagged) +
  geom_point(aes(RAD, O3, group=site, color=site), shape=4)+
  facet_grid(lag~season)

RAD_O3_lagged_corr_plot
ggsave("outputs/RAD_O3_lagged_corr_plot.jpeg", plot = RAD_O3_lagged_corr_plot, width = 6, height = 5, dpi = 300)
# Out:
# Warning message:
# "Removed 510 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 510 rows containing missing values (`geom_point()`)."
# plot without title

# %%
### Cross correlation

# %%
df_filtered <- df %>%
  filter(site == "DAV", season == "Summer")

# Cross-correlation function plot (returns a base R plot, not ggplot)
ccf_plot <- ccf(df_filtered$RAD, df_filtered$O3, lag.max = 6, na.action = na.pass,  main = "RAD and O3")

# Save the plot with a custom title
jpeg("outputs/lagged_visualization_RAD_O3.jpeg", width = 6, height = 5, units = "in", res = 300)
ccf(df_filtered$RAD, df_filtered$O3, lag.max = 6, na.action = na.pass, main = "RAD and O3")
dev.off()
# Out:
# png
#   2
# Plot with title "RAD and O3"

# %%
df %>%
  filter("BAS"==site & "Summer"==season) %>%
  with(ccf(RAD, O3, lag.max=6, na.action=na.pass))
# Out:
# Plot with title "RAD & O3"

# %%
LaggedCorrelation <- function(pair, ...) {
  out <- ccf(pair[,1], pair[,2], ..., na.action=na.pass, plot=FALSE)
  tibble(lag=out[["lag"]], value=out[["acf"]])
}

lagged.values <- df %>% 
  group_by(site, season) %>%
  do(LaggedCorrelation(select(., RAD, O3), lag.max=6))

# %%
ggplot(lagged.values)+
  geom_segment(aes(x=lag,xend=lag,y=0,yend=value))+
  facet_grid(site~season)+
  xlab("lag (hours)")+
  ylab("Cross correlation coefficient")
# Out:
# plot without title
